# %% [markdown]
# # 01. Importing Libraries

# %%
import os
import math
import random
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import scipy
import numpy as np
import pandas as pd

# %% [markdown]
# # 02. Importing Data

# %%
data = pd.read_pickle("../Data/Clean_data/web_funnel_sorted.pkl")

# %%
test_data = pd.read_csv("../Data/Clean_data/df_final_experiment_clients_cleaned.csv")

# %%
data.head()
# Out:
#         client_id             visitor_id                      visit_id  \
# 265216    9088444  242404224_96732670250  423038079_46067236368_400417
# 134323    7179755  167765295_97487764427   264484508_5982901710_928530
# 134324    7179755  167765295_97487764427   264484508_5982901710_928530
# 134325    7179755  167765295_97487764427   264484508_5982901710_928530
# 134326    7179755  167765295_97487764427   264484508_5982901710_928530
#
#        process_step           date_time source
# 265216       step_3 2017-03-15 00:03:03    pt1
# 134323        start 2017-03-15 00:19:28    pt1
# 134324       step_1 2017-03-15 00:20:50    pt1
# 134325       step_2 2017-03-15 00:22:52    pt1
# 134326       step_3 2017-03-15 00:23:47    pt1

# %%
test_data.head()
# Out:
#    client_id group_test
# 0    9988021       test
# 1    8320017       test
# 2    4033851    control
# 3    1982004       test
# 4    9294070    control

# %%
data.shape
# Out:
# (744641, 6)

# %%
test_data.shape
# Out:
# (70609, 2)

# %%
data.index
# Out:
# Index([265216, 134323, 134324, 134325, 134326, 134327, 501516, 501517, 501518,
#        501519,
#        ...
#        450078, 450079, 557322, 557323, 557324, 212626, 212627, 212628, 710463,
#        490849],
#       dtype='int64', length=744641)

# %%
data.sort_index(inplace=True)

# %%
data.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0    3561384   451664975_1722933822  100012776_37918976071_457913
# 1    3561384   451664975_1722933822  100012776_37918976071_457913
# 2    9056452  306992881_89423906595     1000165_4190026492_760066
# 3    9056452  306992881_89423906595     1000165_4190026492_760066
# 4    9056452  306992881_89423906595     1000165_4190026492_760066
#
#   process_step           date_time source
# 0      confirm 2017-04-26 13:22:17    pt1
# 1      confirm 2017-04-26 13:23:09    pt1
# 2        start 2017-06-04 01:07:29    pt2
# 3       step_1 2017-06-04 01:07:32    pt2
# 4       step_2 2017-06-04 01:07:56    pt2

# %%
final_test_data = pd.merge(data, test_data, on='client_id')

# %%
final_test_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         3561384   451664975_1722933822  100012776_37918976071_457913
# 1         3561384   451664975_1722933822  100012776_37918976071_457913
# 2         7338123  612065484_94198474375   100019538_17884295066_43909
# 3         7338123  612065484_94198474375   100019538_17884295066_43909
# 4         7338123  612065484_94198474375   100019538_17884295066_43909
# ...           ...                    ...                           ...
# 443892    6627522  730634087_44272418812  999988789_76411676596_272843
# 443893    6627522  730634087_44272418812  999988789_76411676596_272843
# 443894    6627522  730634087_44272418812  999988789_76411676596_272843
# 443895    6627522  730634087_44272418812  999988789_76411676596_272843
# 443896    3761538  522028589_37033306085  999991142_15352368745_399725
#
#        process_step           date_time source group_test
# ...

# %%
final_test_data.dtypes
# Out:
# client_id                int64
# visitor_id              object
# visit_id                object
# process_step            object
# date_time       datetime64[ns]
# source                  object
# group_test                 str
# dtype: object

# %%
# exporting merged data to csv
final_test_data.to_csv("../Data/Clean_data/final_test_data.csv", index=False)

# %%
# exporting merged data to pkl
final_test_data.to_pickle("../Data/Clean_data/final_test_data.pkl")
