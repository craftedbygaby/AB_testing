# %% [markdown]
# # 01. Importing Libraries

# %%
import os
import math
import random
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import scipy
import numpy as np
import pandas as pd

# %% [markdown]
# # 02. Importing Data

# %%
demo = pd.read_csv('../../IronHack/Unit 5 - EDA and Inferential Stats/Group Project/Data/df_final_demo.txt')

# %%
clients = pd.read_csv('../../IronHack/Unit 5 - EDA and Inferential Stats/Group Project/Data/df_final_experiment_clients.txt')

# %%
demo.shape
# Out:
# (70609, 9)

# %%
clients.shape
# Out:
# (70609, 2)

# %% [markdown]
# # 03. Analysis and Cleaning

# %%
clients.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %% [markdown]
# #### Cleaning clients

# %%
clients.dtypes
# Out:
# client_id    int64
# Variation      str
# dtype: object

# %%
# renaming columns for better understanding and best practices
clients.rename(columns={'Variation': 'group_test'}, inplace=True)

# %%
clients.head()
# Out:
#    client_id group_test
# 0    9988021       Test
# 1    8320017       Test
# 2    4033851    Control
# 3    1982004       Test
# 4    9294070    Control

# %%
# checking for nulls
clients.isnull().sum()
# Out:
# client_id         0
# group_test    20109
# dtype: int64

# %%
clients['group_test'].value_counts()
# Out:
# group_test
# Test       26968
# Control    23532
# Name: count, dtype: int64

# %% [markdown]
# For now, the nulls on the column 'group_test' will be kept and no imputation/drop will be done. Most likely we will drop the rows in the future, once possible dfs are merged or just ignored on possible groupby in python or SQL

# %%
# trimming whitespaces and converting to lowercase for consistency
clients['group_test'] = clients['group_test'].str.strip().str.lower()

# %%
clients['group_test'].value_counts()
# Out:
# group_test
# test       26968
# control    23532
# Name: count, dtype: int64

# %%
# checking for duplicates
clients.duplicated().sum()
# Out:
# np.int64(0)

# %%
# exporting clients cleaned data
clients.to_csv('../../IronHack/Unit 5 - EDA and Inferential Stats/Group Project/Data/df_final_experiment_clients_cleaned.csv', index=False)

# %% [markdown]
# #### Cleaning demo

# %%
demo.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %%
demo.dtypes
# Out:
# client_id             int64
# clnt_tenure_yr      float64
# clnt_tenure_mnth    float64
# clnt_age            float64
# gendr                   str
# num_accts           float64
# bal                 float64
# calls_6_mnth        float64
# logons_6_mnth       float64
# dtype: object

# %%
# renaming columns for better understanding and best practices
demo.rename(columns={'clnt_tenure_yr': 'tenure_years', 'clnt_tenure_mnth': 'tenure_months', 'clnt_age': 'age', 'gendr': 'gender', 'bal': 'balance', 'calls_6_mnth': 'calls_last_6_months', 'logons_6_mnth': 'logons_last_6_months'}, inplace=True)

# %%
# checking if the renaming was successful
demo.head()
# Out:
#    client_id  tenure_years  tenure_months   age gender  num_accts    balance  \
# 0     836976           6.0           73.0  60.5      U        2.0   45105.30
# 1    2304905           7.0           94.0  58.0      U        2.0  110860.30
# 2    1439522           5.0           64.0  32.0      U        2.0   52467.79
# 3    1562045          16.0          198.0  49.0      M        2.0   67454.65
# 4    5126305          12.0          145.0  33.0      F        2.0  103671.75
#
#    calls_last_6_months  logons_last_6_months
# 0                  6.0                   9.0
# 1                  6.0                   9.0
# 2                  6.0                   9.0
# 3                  3.0                   6.0
# 4                  0.0                   3.0

# %%
demo.isnull().sum()
# Out:
# client_id                0
# tenure_years            14
# tenure_months           14
# age                     15
# gender                  14
# num_accts               14
# balance                 14
# calls_last_6_months     14
# logons_last_6_months    14
# dtype: int64

# %%
# checking the rows that have null values (if the same rows or spread around the dataset)
demo[demo.isnull().any(axis=1)]
# Out:
#        client_id  tenure_years  tenure_months  age gender  num_accts  \
# 4164     7402828           NaN            NaN  NaN    NaN        NaN
# 8316      355337           NaN            NaN  NaN    NaN        NaN
# 8677     8412164           NaN            NaN  NaN    NaN        NaN
# 9583     4666211           8.0          106.0  NaN      F        2.0
# 13444    2222915           NaN            NaN  NaN    NaN        NaN
# 18066    4876926           NaN            NaN  NaN    NaN        NaN
# 25961    5277910           NaN            NaN  NaN    NaN        NaN
# 28432    7616759           NaN            NaN  NaN    NaN        NaN
# 35323    8191345           NaN            NaN  NaN    NaN        NaN
# 43518    1227228           NaN            NaN  NaN    NaN        NaN
# 46076    8611797           NaN            NaN  NaN    NaN        NaN
# 47189    5144725           NaN            NaN  NaN    NaN        NaN
# 49846    1037867           NaN            NaN  NaN    NaN        NaN
# ...

# %% [markdown]
# Most rows are the same. For now, the nulls will be kept and no imputation/drop will be done. Most likely we will drop the rows in the future, once possible dfs are merged or just ignored on possible groupby in python or SQL

# %%
# stripping whitespaces for the column gender
demo['gender'] = demo['gender'].str.strip()

# %%
demo['gender'].value_counts()
# Out:
# gender
# U    24122
# M    23724
# F    22746
# X        3
# Name: count, dtype: int64

# %%
# replacing X for U in the gender column
demo['gender'] = demo['gender'].replace('X', 'U')

# %%
# checking if replacing was successful
demo['gender'].value_counts()
# Out:
# gender
# U    24125
# M    23724
# F    22746
# Name: count, dtype: int64

# %%
# checking for duplicates
demo.duplicated().sum()
# Out:
# np.int64(0)

# %%
# exporting cleaned demo dataset
demo.to_csv('../../IronHack/Unit 5 - EDA and Inferential Stats/Group Project/Data/df_final_demo_cleaned.csv', index=False)
